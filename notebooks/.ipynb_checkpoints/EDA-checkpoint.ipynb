# %% [markdown]
# ## Demographics Summary

# %%
import pandas as pd

#path to demographics summary file
demo_path = ("../data/demographics_P2.xlsx")

demographics = pd.read_excel(demo_path, keep_default_na = False)

display(demographics.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_713a6">
#   <thead>
#     <tr>
#       <th id="T_713a6_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_713a6_level0_col1" class="col_heading level0 col1" >Subcategory</th>
#       <th id="T_713a6_level0_col2" class="col_heading level0 col2" >CAT (N=53)</th>
#       <th id="T_713a6_level0_col3" class="col_heading level0 col3" >Any Blood (N=151)</th>
#       <th id="T_713a6_level0_col4" class="col_heading level0 col4" >Total (N=1202)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_713a6_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_713a6_row0_col1" class="data row0 col1" ></td>
#       <td id="T_713a6_row0_col2" class="data row0 col2" ></td>
#       <td id="T_713a6_row0_col3" class="data row0 col3" ></td>
#       <td id="T_713a6_row0_col4" class="data row0 col4" ></td>
#     </tr>
#     <tr>
#       <td id="T_713a6_row1_col0" class="data row1 col0" ></td>
# ...

# %% [markdown]
# ## Features Analysis

# %%
#path to features file
features_path = ("../data/features_P2_inH_15min.xlsx")

features = pd.read_excel(features_path, index_col = 0)

features.head()
# Out:
#         CAT Any Blood  HR_Mean  HR_STD  HR_Variance  HR_Min  HR_Max  \
# id
# P2_0001  NO        NO   79.973   1.938        3.754    74.0    86.0
# P2_0002  NO        NO   65.349   2.238        5.008    60.0    71.0
# P2_0003  NO        NO   54.646   3.524       12.419    48.0    64.0
# P2_0004  NO        NO  100.745   2.190        4.794    97.0   106.0
# P2_0005  NO        NO  108.277   1.692        2.862   105.0   112.0
#
#          HR_CoeffOfVar  HR_10pctl  HR_20pctl  ...  S2_mode  S1S2ratio_min  \
# id                                            ...
# P2_0001          0.925       78.0       79.0  ...   50.000          0.045
# P2_0002          0.918       63.0       63.0  ...   51.000          0.052
# P2_0003          0.878       51.0       52.0  ...   57.175          0.034
# P2_0004          0.963       98.0       99.0  ...   31.000          0.038
# P2_0005          0.970      106.0      107.0  ...   44.000          0.018
#
# ...

# %% [markdown]
# ### Split into CAT and non CAT cases

# %%
#creating a mask for CAT cases
CAT_cases = features["CAT"] == "YES"

#separating dataframe into CAT and non CAT
CAT_features = features[CAT_cases]

non_CAT_features = features[~CAT_cases]

# %%
print("Total cases: " + str(len(features.index)))
print("CAT cases: " + str(len(CAT_features.index)))
print("non_CAT cases: " + str(len(non_CAT_features.index)))
# Out:
# Total cases: 1202
# CAT cases: 53
# non_CAT cases: 1149

# %% [markdown]
# ### Column Missingness Check

# %%
#I'm using one column to represent each vital sign since if one feature is null, all features will be null
CAT_features[["HR_Mean", "SPO2p_Mean", "SBP_Mean", "MBP_Mean", "DBP_Mean", "RESP_Mean", "SI_Mean", "PP_Mean", "ECG2w_meanNN", "PPGw_meanNN"\
, "QRrise_time_min", "RSfall_time_min", "sys_crest_time_min", "sys_fall_time_min", "dia_fall_time_min", "normalization_time_min", "a2b_time_max"\
, "a2b_amp_min", "e2dp_amp_min", "S1_min", "S2_min", "S1S2ratio_min", "dnotchpospct"]].isna().sum()
# Out:
# HR_Mean                   0
# SPO2p_Mean                2
# SBP_Mean                  2
# MBP_Mean                  2
# DBP_Mean                  2
# RESP_Mean                 0
# SI_Mean                   2
# PP_Mean                   2
# ECG2w_meanNN              0
# PPGw_meanNN               1
# QRrise_time_min           0
# RSfall_time_min           0
# sys_crest_time_min        1
# sys_fall_time_min         1
# dia_fall_time_min         1
# normalization_time_min    1
# a2b_time_max              1
# a2b_amp_min               1
# e2dp_amp_min              1
# S1_min                    1
# S2_min                    1
# S1S2ratio_min             1
# dnotchpospct              1
# dtype: int64

# %%
non_CAT_features[["HR_Mean", "SPO2p_Mean", "SBP_Mean", "MBP_Mean", "DBP_Mean", "RESP_Mean", "SI_Mean", "PP_Mean", "ECG2w_meanNN", "PPGw_meanNN"\
, "QRrise_time_min", "RSfall_time_min", "sys_crest_time_min", "sys_fall_time_min", "dia_fall_time_min", "normalization_time_min", "a2b_time_max"\
, "a2b_amp_min", "e2dp_amp_min", "S1_min", "S2_min", "S1S2ratio_min", "dnotchpospct"]].isna().sum()
# Out:
# HR_Mean                    20
# SPO2p_Mean                 37
# SBP_Mean                   79
# MBP_Mean                   78
# DBP_Mean                   78
# RESP_Mean                  39
# SI_Mean                   138
# PP_Mean                    79
# ECG2w_meanNN               27
# PPGw_meanNN                25
# QRrise_time_min            27
# RSfall_time_min            27
# sys_crest_time_min         25
# sys_fall_time_min          25
# dia_fall_time_min          25
# normalization_time_min     25
# a2b_time_max               25
# a2b_amp_min                25
# e2dp_amp_min               25
# S1_min                     25
# S2_min                     25
# S1S2ratio_min              25
# dnotchpospct               25
# dtype: int64

# %% [markdown]
# One thing we can also see from this check is that QRrise and RSfall are tied to ECG data and sys_crest, sys_fall, ... dnotch are tied to PPG data

# %% [markdown]
# ### Create Vital Signs Heatmaps

# %%
import plotly.express as px
from scipy.cluster.hierarchy import linkage, leaves_list

#define which vital signs to plot (ignoring SI(Shock Index) since is a ratio)
vital_signs = ["HR", "SPO2p", "SBP", "MBP", "DBP", "RESP", "PP"]

#define ranges for the variables for the heatmap to compare between CAT and non CAT
ranges = {
    "HR": (0,200),
    "SPO2p": (20,100),
    "SBP": (20, 300),
    "MBP": (0, 200),
    "DBP": (0, 180),
    "RESP": (0,90),
    "PP": (0, 150)
}

for vs in vital_signs:
    #define percentile columns to plot
    percentile_cols = [vs+'_10pctl', vs+'_20pctl', vs+'_30pctl', vs+'_40pctl', vs+'_Median', vs+'_60pctl', vs+'_70pctl', vs+'_80pctl', vs+'_90pctl']

    #process CAT features
    cut_df = CAT_features[percentile_cols].copy()

    #remove empty rows
    cut_df[percentile_cols] = cut_df[percentile_cols].apply(
        pd.to_numeric,
        errors='coerce'
    )
    
    cut_df = cut_df.dropna()

    #apply sorting
    df_sorted = cut_df.sort_values(vs+'_Median')

    #configure plot
    fig = px.imshow(
        df_sorted,
        aspect="auto",
        color_continuous_scale="Viridis",
        labels={
            "x": "Percentile",
            "y": "Case",
            "color": "Value"
        },
        title="CAT " + vs + " Heatmap",
        zmin=ranges[vs][0],
        zmax=ranges[vs][1]
    )

    #remove labels
    fig.update_yaxes(showticklabels=False)

    #save to interactive html
    fig.write_html(
        "CAT " + vs + " Heatmap.html",
        include_plotlyjs="cdn",
        auto_open=True
    )

    #process non CAT features
    cut_df = non_CAT_features[percentile_cols].copy()

    #remove empty rows
    cut_df[percentile_cols] = cut_df[percentile_cols].apply(
        pd.to_numeric,
        errors='coerce'
    )
    
    cut_df = cut_df.dropna()

    #apply sorting
    df_sorted = cut_df.sort_values(vs+'_Median')

    #configure plot
    fig = px.imshow(
        df_sorted,
        aspect="auto",
        color_continuous_scale="Viridis",
        labels={
            "x": "Percentile",
            "y": "Case",
            "color": "Value"
        },
        title="non CAT " + vs + " Heatmap",
        zmin=ranges[vs][0],
        zmax=ranges[vs][1]
    )

    #remove labels
    fig.update_yaxes(showticklabels=False)

    #save to interactive html
    fig.write_html(
        "non CAT " + vs + " Heatmap.html",
        include_plotlyjs="cdn",
        auto_open=True
    )
